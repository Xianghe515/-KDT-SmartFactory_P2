# %%
import RPi.GPIO as gpio
import time

TRIGER = 24   # 트리거 GPIO
ECHO = 23     # 에코 GPIO

gpio.setmode(gpio.BCM)
gpio.setup(TRIGER, gpio.OUT)
gpio.setup(ECHO, gpio.IN)

startTime = time.time()

try:
    while True:
		    # Triger로 출력 신호 전송
        gpio.output(TRIGER, gpio.LOW)    # 출력 off
        time.sleep(0.1)
        gpio.output(TRIGER, gpio.HIGH)   # 출력 on
        time.sleep(0.00002)
        gpio.output(TRIGER, gpio.LOW)    # 출력 off

        while gpio.input(ECHO) == gpio.LOW:  # 출력 감지 - triger가 off인 경우
            startTime = time.time()      # 시작 시간

        while gpio.input(ECHO) == gpio.HIGH: # 출력 감지 O -> triger가 on인 경우.. 
            endTime = time.time()        # 감지 시간

        period = endTime - startTime     # 신호 감지 간격
        dist1 = round(period * 1000000 / 58, 2)   # 거리 계산, 2로 라운드 처리 이유는 왕복시간을 통해서 거리를 측정하기 때문
        dist2 = round(period * 17241, 2)

        print("Dist1", dist1, "cm", ", Dist2", dist2, "cm")

        if dist1 < 10 and dist2 < 10:    # 감지 거리가 10cm 미만인 경우 감지 처리
            print("detect")

except:
    print("종료")
    gpio.cleanup()
# Out:
# Dist1 250.19 cm , Dist2 250.19 cm
# Dist1 259.87 cm , Dist2 259.87 cm
# Dist1 805.74 cm , Dist2 805.72 cm
# Dist1 259.01 cm , Dist2 259.0 cm
# Dist1 805.81 cm , Dist2 805.8 cm
# Dist1 805.57 cm , Dist2 805.55 cm
# Dist1 260.3 cm , Dist2 260.3 cm
# Dist1 80.65 cm , Dist2 80.65 cm
# Dist1 80.16 cm , Dist2 80.16 cm
# Dist1 17.15 cm , Dist2 17.15 cm
# Dist1 259.41 cm , Dist2 259.4 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 259.84 cm , Dist2 259.83 cm
# Dist1 16.96 cm , Dist2 16.96 cm
# Dist1 16.96 cm , Dist2 16.96 cm
# Dist1 259.49 cm , Dist2 259.48 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 805.25 cm , Dist2 805.24 cm
# Dist1 16.99 cm , Dist2 16.98 cm
# Dist1 259.88 cm , Dist2 259.87 cm
# Dist1 259.89 cm , Dist2 259.89 cm
# Dist1 265.71 cm , Dist2 265.7 cm
# Dist1 805.63 cm , Dist2 805.61 cm
# Dist1 258.98 cm , Dist2 258.97 cm
# Dist1 805.8 cm , Dist2 805.78 cm
# Dist1 259.52 cm , Dist2 259.52 cm
# Dist1 805.53 cm , Dist2 805.51 cm
# Dist1 805.93 cm , Dist2 805.92 cm
# Dist1 805.32 cm , Dist2 805.3 cm
# Dist1 260.46 cm , Dist2 260.46 cm
# Dist1 805.37 cm , Dist2 805.35 cm
# Dist1 259.65 cm , Dist2 259.64 cm
# Dist1 805.29 cm , Dist2 805.27 cm
# Dist1 805.63 cm , Dist2 805.62 cm
# Dist1 259.19 cm , Dist2 259.18 cm
# Dist1 259.11 cm , Dist2 259.11 cm
# Dist1 260.4 cm , Dist2 260.4 cm
# Dist1 259.85 cm , Dist2 259.85 cm
# Dist1 270.2 cm , Dist2 270.19 cm
# Dist1 805.61 cm , Dist2 805.59 cm
# Dist1 259.18 cm , Dist2 259.17 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 806.15 cm , Dist2 806.13 cm
# Dist1 259.18 cm , Dist2 259.18 cm
# Dist1 805.58 cm , Dist2 805.57 cm
# Dist1 259.53 cm , Dist2 259.53 cm
# Dist1 259.98 cm , Dist2 259.97 cm
# Dist1 258.73 cm , Dist2 258.72 cm
# Dist1 259.63 cm , Dist2 259.62 cm
# Dist1 259.18 cm , Dist2 259.18 cm
# Dist1 805.56 cm , Dist2 805.54 cm
# Dist1 259.14 cm , Dist2 259.13 cm
# Dist1 805.44 cm , Dist2 805.42 cm
# Dist1 259.51 cm , Dist2 259.51 cm
# Dist1 259.91 cm , Dist2 259.91 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 0.8 cm , Dist2 0.8 cm
# detect
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 12.26 cm , Dist2 12.26 cm
# Dist1 49.7 cm , Dist2 49.7 cm
# Dist1 15.91 cm , Dist2 15.91 cm
# Dist1 13.7 cm , Dist2 13.7 cm
# Dist1 22.08 cm , Dist2 22.08 cm
# Dist1 11.59 cm , Dist2 11.59 cm
# Dist1 13.3 cm , Dist2 13.3 cm
# Dist1 13.27 cm , Dist2 13.27 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.57 cm , Dist2 11.57 cm
# Dist1 11.59 cm , Dist2 11.59 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 10.25 cm , Dist2 10.25 cm
# Dist1 10.22 cm , Dist2 10.22 cm
# Dist1 11.06 cm , Dist2 11.06 cm
# Dist1 11.84 cm , Dist2 11.84 cm
# Dist1 10.23 cm , Dist2 10.23 cm
# Dist1 10.23 cm , Dist2 10.23 cm
# Dist1 10.44 cm , Dist2 10.44 cm
# Dist1 10.22 cm , Dist2 10.21 cm
# Dist1 10.22 cm , Dist2 10.22 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.54 cm , Dist2 10.54 cm
# Dist1 10.54 cm , Dist2 10.54 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 6.21 cm , Dist2 6.21 cm
# detect
# Dist1 2.89 cm , Dist2 2.89 cm
# detect
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 11.57 cm , Dist2 11.57 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.93 cm , Dist2 11.92 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 10.6 cm , Dist2 10.6 cm
# Dist1 10.59 cm , Dist2 10.59 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.93 cm , Dist2 11.92 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 12.32 cm , Dist2 12.32 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 12.71 cm , Dist2 12.71 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.93 cm , Dist2 11.92 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.94 cm , Dist2 11.94 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 13.64 cm , Dist2 13.63 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 12.31 cm , Dist2 12.31 cm
# Dist1 12.32 cm , Dist2 12.32 cm
# Dist1 10.59 cm , Dist2 10.59 cm
# Dist1 0.24 cm , Dist2 0.24 cm
# detect
# Dist1 259.86 cm , Dist2 259.86 cm
# Dist1 56.51 cm , Dist2 56.5 cm
# Dist1 2106.88 cm , Dist2 2106.83 cm
# Dist1 259.07 cm , Dist2 259.06 cm
# Dist1 259.13 cm , Dist2 259.12 cm
# Dist1 259.08 cm , Dist2 259.07 cm
# Dist1 259.92 cm , Dist2 259.92 cm
# Dist1 284.52 cm , Dist2 284.51 cm
# Dist1 259.51 cm , Dist2 259.51 cm
# Dist1 259.06 cm , Dist2 259.05 cm
# Dist1 259.81 cm , Dist2 259.8 cm
# Dist1 259.49 cm , Dist2 259.48 cm
# Dist1 259.96 cm , Dist2 259.96 cm
# Dist1 805.72 cm , Dist2 805.71 cm
# Dist1 259.86 cm , Dist2 259.85 cm
# Dist1 805.3 cm , Dist2 805.29 cm
# Dist1 253.33 cm , Dist2 253.32 cm
# Dist1 805.91 cm , Dist2 805.89 cm
# Dist1 259.85 cm , Dist2 259.85 cm
# Dist1 805.75 cm , Dist2 805.73 cm
# Dist1 259.01 cm , Dist2 259.01 cm
# Dist1 259.84 cm , Dist2 259.83 cm
# Dist1 258.97 cm , Dist2 258.96 cm
# Dist1 260.22 cm , Dist2 260.21 cm
# Dist1 259.79 cm , Dist2 259.78 cm
# Dist1 805.33 cm , Dist2 805.32 cm
# Dist1 807.92 cm , Dist2 807.9 cm
# Dist1 261.29 cm , Dist2 261.28 cm
# Dist1 259.33 cm , Dist2 259.32 cm
# Dist1 260.16 cm , Dist2 260.15 cm
# Dist1 254.59 cm , Dist2 254.58 cm
# Dist1 258.87 cm , Dist2 258.87 cm
# Dist1 259.28 cm , Dist2 259.27 cm
# Dist1 259.31 cm , Dist2 259.31 cm
# Dist1 260.14 cm , Dist2 260.14 cm
# Dist1 258.88 cm , Dist2 258.87 cm
# Dist1 259.26 cm , Dist2 259.25 cm
# Dist1 2246.32 cm , Dist2 2246.27 cm
# Dist1 4389.5 cm , Dist2 4389.4 cm
# Dist1 258.92 cm , Dist2 258.91 cm
# Dist1 263.61 cm , Dist2 263.6 cm
# Dist1 2304.8 cm , Dist2 2304.75 cm
# Dist1 258.92 cm , Dist2 258.92 cm
# Dist1 258.92 cm , Dist2 258.92 cm
# Dist1 255.4 cm , Dist2 255.39 cm
# Dist1 259.74 cm , Dist2 259.73 cm
# Dist1 245.66 cm , Dist2 245.65 cm
# Dist1 259.7 cm , Dist2 259.69 cm
# Dist1 290.87 cm , Dist2 290.87 cm
# Dist1 2330.83 cm , Dist2 2330.78 cm
# Dist1 258.89 cm , Dist2 258.89 cm
# Dist1 258.45 cm , Dist2 258.44 cm
# Dist1 258.88 cm , Dist2 258.87 cm
# Dist1 257.93 cm , Dist2 257.93 cm
# Dist1 277.0 cm , Dist2 277.0 cm
# Dist1 2290.16 cm , Dist2 2290.11 cm
# Dist1 258.92 cm , Dist2 258.92 cm
# Dist1 258.48 cm , Dist2 258.47 cm
# Dist1 260.21 cm , Dist2 260.2 cm
# Dist1 260.65 cm , Dist2 260.64 cm
# Dist1 259.32 cm , Dist2 259.32 cm
# Dist1 259.33 cm , Dist2 259.33 cm
# Dist1 260.21 cm , Dist2 260.2 cm
# Dist1 259.74 cm , Dist2 259.74 cm
# Dist1 259.7 cm , Dist2 259.7 cm
# Dist1 805.25 cm , Dist2 805.23 cm
# Dist1 805.45 cm , Dist2 805.43 cm
# Dist1 259.24 cm , Dist2 259.23 cm
# Dist1 258.77 cm , Dist2 258.76 cm
# Dist1 259.67 cm , Dist2 259.67 cm
# Dist1 259.67 cm , Dist2 259.66 cm
# Dist1 805.89 cm , Dist2 805.87 cm
# Dist1 259.28 cm , Dist2 259.28 cm
# Dist1 805.52 cm , Dist2 805.5 cm
# Dist1 805.41 cm , Dist2 805.39 cm
# Dist1 805.84 cm , Dist2 805.82 cm
# Dist1 260.34 cm , Dist2 260.34 cm
# Dist1 805.67 cm , Dist2 805.65 cm
# Dist1 259.0 cm , Dist2 259.0 cm
# Dist1 259.49 cm , Dist2 259.48 cm
# Dist1 259.43 cm , Dist2 259.42 cm
# Dist1 259.41 cm , Dist2 259.41 cm
# Dist1 259.83 cm , Dist2 259.82 cm
# Dist1 259.34 cm , Dist2 259.33 cm
# Dist1 271.61 cm , Dist2 271.61 cm
# Dist1 258.59 cm , Dist2 258.59 cm
# Dist1 790.95 cm , Dist2 790.94 cm
# Dist1 259.02 cm , Dist2 259.01 cm
# Dist1 258.61 cm , Dist2 258.61 cm
# Dist1 2312.17 cm , Dist2 2312.12 cm
# Dist1 259.06 cm , Dist2 259.06 cm
# Dist1 259.05 cm , Dist2 259.04 cm
# Dist1 259.03 cm , Dist2 259.02 cm
# Dist1 258.63 cm , Dist2 258.62 cm
# Dist1 259.41 cm , Dist2 259.4 cm
# Dist1 2294.01 cm , Dist2 2293.96 cm
# Dist1 262.29 cm , Dist2 262.28 cm
# Dist1 259.79 cm , Dist2 259.78 cm
# Dist1 805.38 cm , Dist2 805.36 cm
# Dist1 259.54 cm , Dist2 259.53 cm
# Dist1 258.32 cm , Dist2 258.32 cm
# Dist1 259.17 cm , Dist2 259.17 cm
# Dist1 260.03 cm , Dist2 260.02 cm
# Dist1 805.44 cm , Dist2 805.42 cm
# Dist1 259.21 cm , Dist2 259.2 cm
# Dist1 238.6 cm , Dist2 238.59 cm
# Dist1 818.65 cm , Dist2 818.63 cm
# Dist1 805.58 cm , Dist2 805.56 cm
# Dist1 260.41 cm , Dist2 260.4 cm
# Dist1 259.11 cm , Dist2 259.11 cm
# Dist1 805.51 cm , Dist2 805.5 cm
# Dist1 259.49 cm , Dist2 259.49 cm
# Dist1 259.5 cm , Dist2 259.5 cm
# Dist1 259.13 cm , Dist2 259.12 cm
# Dist1 270.4 cm , Dist2 270.4 cm
# Dist1 261.27 cm , Dist2 261.27 cm
# Dist1 805.46 cm , Dist2 805.44 cm
# Dist1 259.4 cm , Dist2 259.39 cm
# Dist1 805.48 cm , Dist2 805.47 cm
# Dist1 259.34 cm , Dist2 259.34 cm
# Dist1 255.29 cm , Dist2 255.29 cm
# Dist1 16.38 cm , Dist2 16.38 cm
# Dist1 16.71 cm , Dist2 16.71 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.59 cm , Dist2 11.59 cm
# Dist1 13.5 cm , Dist2 13.5 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 10.23 cm , Dist2 10.23 cm
# Dist1 11.57 cm , Dist2 11.57 cm
# Dist1 10.14 cm , Dist2 10.14 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 9.91 cm , Dist2 9.91 cm
# detect
# Dist1 11.24 cm , Dist2 11.24 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.54 cm , Dist2 10.54 cm
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 11.24 cm , Dist2 11.24 cm
# Dist1 11.25 cm , Dist2 11.25 cm
# Dist1 11.22 cm , Dist2 11.22 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 10.24 cm , Dist2 10.24 cm
# Dist1 11.23 cm , Dist2 11.23 cm
# Dist1 11.25 cm , Dist2 11.25 cm
# Dist1 11.24 cm , Dist2 11.24 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.98 cm , Dist2 11.98 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 1800.84 cm , Dist2 1800.8 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 12.27 cm , Dist2 12.27 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 12.29 cm , Dist2 12.29 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 12.28 cm , Dist2 12.28 cm
# Dist1 14.61 cm , Dist2 14.61 cm
# Dist1 14.01 cm , Dist2 14.01 cm
# Dist1 12.27 cm , Dist2 12.27 cm
# Dist1 12.26 cm , Dist2 12.26 cm
# Dist1 11.94 cm , Dist2 11.94 cm
# Dist1 13.65 cm , Dist2 13.65 cm
# Dist1 13.65 cm , Dist2 13.65 cm
# Dist1 12.3 cm , Dist2 12.3 cm
# Dist1 12.29 cm , Dist2 12.29 cm
# Dist1 12.32 cm , Dist2 12.32 cm
# Dist1 12.29 cm , Dist2 12.29 cm
# Dist1 12.31 cm , Dist2 12.31 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 12.26 cm , Dist2 12.26 cm
# Dist1 10.93 cm , Dist2 10.93 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 10.39 cm , Dist2 10.39 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 10.94 cm , Dist2 10.94 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 9.09 cm , Dist2 9.09 cm
# detect
# Dist1 10.23 cm , Dist2 10.23 cm
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 11.57 cm , Dist2 11.57 cm
# Dist1 11.59 cm , Dist2 11.59 cm
# Dist1 11.57 cm , Dist2 11.57 cm
# Dist1 13.38 cm , Dist2 13.38 cm
# Dist1 12.95 cm , Dist2 12.95 cm
# Dist1 14.65 cm , Dist2 14.65 cm
# Dist1 13.31 cm , Dist2 13.31 cm
# Dist1 13.29 cm , Dist2 13.29 cm
# Dist1 13.68 cm , Dist2 13.68 cm
# Dist1 12.31 cm , Dist2 12.31 cm
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 12.26 cm , Dist2 12.26 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 14.05 cm , Dist2 14.05 cm
# Dist1 16.05 cm , Dist2 16.05 cm
# Dist1 15.05 cm , Dist2 15.04 cm
# Dist1 14.65 cm , Dist2 14.65 cm
# Dist1 11.97 cm , Dist2 11.97 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 12.29 cm , Dist2 12.29 cm
# Dist1 14.99 cm , Dist2 14.99 cm
# Dist1 12.96 cm , Dist2 12.96 cm
# Dist1 16.04 cm , Dist2 16.04 cm
# Dist1 13.29 cm , Dist2 13.29 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 17.01 cm , Dist2 17.01 cm
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 13.27 cm , Dist2 13.27 cm
# Dist1 13.67 cm , Dist2 13.67 cm
# Dist1 13.28 cm , Dist2 13.28 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 1.06 cm , Dist2 1.06 cm
# detect
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.65 cm , Dist2 13.65 cm
# Dist1 13.61 cm , Dist2 13.61 cm
# Dist1 13.55 cm , Dist2 13.55 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 13.67 cm , Dist2 13.67 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 13.64 cm , Dist2 13.63 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.63 cm , Dist2 13.63 cm
# Dist1 14.02 cm , Dist2 14.02 cm
# Dist1 13.15 cm , Dist2 13.15 cm
# Dist1 13.62 cm , Dist2 13.62 cm
# Dist1 13.66 cm , Dist2 13.66 cm
# Dist1 15.34 cm , Dist2 15.34 cm
# Dist1 15.33 cm , Dist2 15.33 cm
# Dist1 9.78 cm , Dist2 9.78 cm
# detect
# Dist1 15.33 cm , Dist2 15.33 cm
# Dist1 15.32 cm , Dist2 15.32 cm
# Dist1 15.33 cm , Dist2 15.33 cm
# Dist1 13.98 cm , Dist2 13.98 cm
# Dist1 14.01 cm , Dist2 14.0 cm
# Dist1 16.63 cm , Dist2 16.63 cm
# Dist1 1806.86 cm , Dist2 1806.82 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 13.97 cm , Dist2 13.97 cm
# Dist1 12.57 cm , Dist2 12.57 cm
# Dist1 1807.4 cm , Dist2 1807.36 cm
# Dist1 14.0 cm , Dist2 14.0 cm
# Dist1 13.98 cm , Dist2 13.98 cm
# Dist1 21.18 cm , Dist2 21.18 cm
# Dist1 16.94 cm , Dist2 16.94 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 4.53 cm , Dist2 4.53 cm
# detect
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 11.23 cm , Dist2 11.23 cm
# Dist1 805.04 cm , Dist2 805.02 cm
# Dist1 13.64 cm , Dist2 13.64 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 10.57 cm , Dist2 10.57 cm
# Dist1 11.16 cm , Dist2 11.16 cm
# Dist1 10.59 cm , Dist2 10.59 cm
# Dist1 10.58 cm , Dist2 10.58 cm
# Dist1 10.57 cm , Dist2 10.57 cm
# Dist1 10.59 cm , Dist2 10.59 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 10.57 cm , Dist2 10.57 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.57 cm , Dist2 10.57 cm
# Dist1 1801.17 cm , Dist2 1801.13 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 12.27 cm , Dist2 12.27 cm
# Dist1 3.72 cm , Dist2 3.72 cm
# detect
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 10.91 cm , Dist2 10.91 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 9.19 cm , Dist2 9.19 cm
# detect
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 10.89 cm , Dist2 10.88 cm
# Dist1 10.91 cm , Dist2 10.91 cm
# Dist1 10.52 cm , Dist2 10.52 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 22.81 cm , Dist2 22.81 cm
# Dist1 10.55 cm , Dist2 10.55 cm
# Dist1 0.95 cm , Dist2 0.95 cm
# detect
# Dist1 10.92 cm , Dist2 10.92 cm
# Dist1 17.61 cm , Dist2 17.61 cm
# Dist1 10.91 cm , Dist2 10.91 cm
# Dist1 10.92 cm , Dist2 10.92 cm
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 10.92 cm , Dist2 10.92 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 10.88 cm , Dist2 10.88 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 38.33 cm , Dist2 38.33 cm
# Dist1 16.7 cm , Dist2 16.7 cm
# Dist1 19.22 cm , Dist2 19.22 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 19.24 cm , Dist2 19.24 cm
# Dist1 1805.93 cm , Dist2 1805.89 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.95 cm , Dist2 16.95 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 805.72 cm , Dist2 805.7 cm
# Dist1 3390.01 cm , Dist2 3389.94 cm
# Dist1 805.49 cm , Dist2 805.48 cm
# Dist1 66.5 cm , Dist2 66.5 cm
# Dist1 805.46 cm , Dist2 805.44 cm
# Dist1 805.62 cm , Dist2 805.61 cm
# Dist1 19.22 cm , Dist2 19.22 cm
# Dist1 24.0 cm , Dist2 24.0 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 17.02 cm , Dist2 17.02 cm
# Dist1 16.65 cm , Dist2 16.65 cm
# Dist1 805.66 cm , Dist2 805.64 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 1798.47 cm , Dist2 1798.43 cm
# Dist1 12.61 cm , Dist2 12.61 cm
# Dist1 12.29 cm , Dist2 12.29 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 10.26 cm , Dist2 10.26 cm
# Dist1 11.25 cm , Dist2 11.25 cm
# Dist1 4.69 cm , Dist2 4.69 cm
# detect
# Dist1 11.97 cm , Dist2 11.97 cm
# Dist1 10.22 cm , Dist2 10.22 cm
# Dist1 10.59 cm , Dist2 10.59 cm
# Dist1 10.56 cm , Dist2 10.56 cm
# Dist1 10.07 cm , Dist2 10.07 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 10.91 cm , Dist2 10.91 cm
# Dist1 10.93 cm , Dist2 10.93 cm
# Dist1 10.89 cm , Dist2 10.89 cm
# Dist1 10.9 cm , Dist2 10.9 cm
# Dist1 11.24 cm , Dist2 11.24 cm
# Dist1 11.26 cm , Dist2 11.26 cm
# Dist1 11.26 cm , Dist2 11.25 cm
# Dist1 11.26 cm , Dist2 11.26 cm
# Dist1 11.27 cm , Dist2 11.27 cm
# Dist1 11.24 cm , Dist2 11.24 cm
# Dist1 12.59 cm , Dist2 12.59 cm
# Dist1 12.6 cm , Dist2 12.6 cm
# Dist1 12.27 cm , Dist2 12.27 cm
# Dist1 16.65 cm , Dist2 16.65 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 16.5 cm , Dist2 16.5 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 16.66 cm , Dist2 16.66 cm
# Dist1 19.2 cm , Dist2 19.2 cm
# Dist1 17.92 cm , Dist2 17.92 cm
# Dist1 22.99 cm , Dist2 22.99 cm
# Dist1 22.97 cm , Dist2 22.97 cm
# Dist1 23.62 cm , Dist2 23.62 cm
# Dist1 51.48 cm , Dist2 51.48 cm
# Dist1 22.09 cm , Dist2 22.09 cm
# Dist1 49.87 cm , Dist2 49.87 cm
# Dist1 1857.68 cm , Dist2 1857.63 cm
# Dist1 74.15 cm , Dist2 74.15 cm
# Dist1 74.14 cm , Dist2 74.14 cm
# Dist1 49.79 cm , Dist2 49.79 cm
# Dist1 22.98 cm , Dist2 22.98 cm
# Dist1 16.3 cm , Dist2 16.3 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 1805.34 cm , Dist2 1805.3 cm
# Dist1 15.96 cm , Dist2 15.96 cm
# Dist1 16.02 cm , Dist2 16.02 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 12.06 cm , Dist2 12.06 cm
# Dist1 13.33 cm , Dist2 13.33 cm
# Dist1 13.29 cm , Dist2 13.29 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 11.64 cm , Dist2 11.64 cm
# Dist1 12.94 cm , Dist2 12.94 cm
# Dist1 12.99 cm , Dist2 12.99 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 16.08 cm , Dist2 16.08 cm
# Dist1 16.36 cm , Dist2 16.36 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 16.02 cm , Dist2 16.01 cm
# Dist1 16.35 cm , Dist2 16.35 cm
# Dist1 16.04 cm , Dist2 16.04 cm
# Dist1 16.03 cm , Dist2 16.03 cm
# Dist1 16.02 cm , Dist2 16.01 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 16.7 cm , Dist2 16.7 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 16.27 cm , Dist2 16.27 cm
# Dist1 17.92 cm , Dist2 17.92 cm
# Dist1 13.29 cm , Dist2 13.29 cm
# Dist1 13.31 cm , Dist2 13.31 cm
# Dist1 13.28 cm , Dist2 13.28 cm
# Dist1 18.29 cm , Dist2 18.29 cm
# Dist1 16.06 cm , Dist2 16.06 cm
# Dist1 18.3 cm , Dist2 18.3 cm
# Dist1 13.29 cm , Dist2 13.29 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 16.0 cm , Dist2 16.0 cm
# Dist1 16.02 cm , Dist2 16.01 cm
# Dist1 16.04 cm , Dist2 16.04 cm
# Dist1 16.03 cm , Dist2 16.03 cm
# Dist1 16.04 cm , Dist2 16.04 cm
# Dist1 16.01 cm , Dist2 16.01 cm
# Dist1 1802.76 cm , Dist2 1802.72 cm
# Dist1 16.31 cm , Dist2 16.31 cm
# Dist1 16.32 cm , Dist2 16.32 cm
# Dist1 16.32 cm , Dist2 16.32 cm
# Dist1 12.65 cm , Dist2 12.65 cm
# Dist1 16.32 cm , Dist2 16.32 cm
# Dist1 16.64 cm , Dist2 16.64 cm
# Dist1 15.96 cm , Dist2 15.96 cm
# Dist1 16.69 cm , Dist2 16.69 cm
# Dist1 15.69 cm , Dist2 15.69 cm
# Dist1 16.71 cm , Dist2 16.71 cm
# Dist1 16.34 cm , Dist2 16.34 cm
# Dist1 17.62 cm , Dist2 17.62 cm
# Dist1 16.68 cm , Dist2 16.68 cm
# Dist1 1809.79 cm , Dist2 1809.75 cm
# Dist1 16.32 cm , Dist2 16.32 cm
# Dist1 16.31 cm , Dist2 16.31 cm
# Dist1 16.69 cm , Dist2 16.68 cm
# Dist1 23.64 cm , Dist2 23.64 cm
# Dist1 12.98 cm , Dist2 12.98 cm
# Dist1 16.38 cm , Dist2 16.38 cm
# Dist1 16.65 cm , Dist2 16.65 cm
# Dist1 1807.23 cm , Dist2 1807.19 cm
# Dist1 74.61 cm , Dist2 74.61 cm
# Dist1 74.15 cm , Dist2 74.15 cm
# Dist1 74.6 cm , Dist2 74.59 cm
# Dist1 74.57 cm , Dist2 74.57 cm
# Dist1 74.16 cm , Dist2 74.16 cm
# Dist1 74.09 cm , Dist2 74.09 cm
# Dist1 74.49 cm , Dist2 74.49 cm
# Dist1 74.03 cm , Dist2 74.03 cm
# Dist1 74.04 cm , Dist2 74.04 cm
# Dist1 74.11 cm , Dist2 74.11 cm
# Dist1 74.6 cm , Dist2 74.6 cm
# Dist1 16.33 cm , Dist2 16.33 cm
# Dist1 12.94 cm , Dist2 12.94 cm
# Dist1 13.2 cm , Dist2 13.19 cm
# Dist1 8.04 cm , Dist2 8.04 cm
# detect
# Dist1 1790.24 cm , Dist2 1790.2 cm
# Dist1 7.19 cm , Dist2 7.19 cm
# detect
# Dist1 7.22 cm , Dist2 7.22 cm
# detect
# Dist1 7.52 cm , Dist2 7.52 cm
# detect
# Dist1 8.86 cm , Dist2 8.86 cm
# detect
# Dist1 7.51 cm , Dist2 7.51 cm
# detect
# Dist1 7.51 cm , Dist2 7.51 cm
# detect
# Dist1 5.1 cm , Dist2 5.1 cm
# detect
# Dist1 1839.21 cm , Dist2 1839.17 cm
# Dist1 7.84 cm , Dist2 7.84 cm
# detect
# Dist1 7.85 cm , Dist2 7.85 cm
# detect
# Dist1 7.62 cm , Dist2 7.62 cm
# detect
# Dist1 8.18 cm , Dist2 8.18 cm
# detect
# Dist1 8.16 cm , Dist2 8.16 cm
# detect
# Dist1 8.16 cm , Dist2 8.16 cm
# detect
# Dist1 13.07 cm , Dist2 13.07 cm
# Dist1 8.16 cm , Dist2 8.16 cm
# detect
# Dist1 7.22 cm , Dist2 7.22 cm
# detect
# Dist1 7.2 cm , Dist2 7.2 cm
# detect
# Dist1 7.19 cm , Dist2 7.19 cm
# detect
# Dist1 7.19 cm , Dist2 7.19 cm
# detect
# Dist1 18.91 cm , Dist2 18.91 cm
# Dist1 13.97 cm , Dist2 13.97 cm
# Dist1 12.61 cm , Dist2 12.61 cm
# Dist1 11.28 cm , Dist2 11.28 cm
# Dist1 1806.6 cm , Dist2 1806.56 cm
# Dist1 12.6 cm , Dist2 12.6 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 12.6 cm , Dist2 12.6 cm
# Dist1 12.63 cm , Dist2 12.63 cm
# Dist1 12.6 cm , Dist2 12.59 cm
# Dist1 12.61 cm , Dist2 12.61 cm
# Dist1 1797.28 cm , Dist2 1797.24 cm
# Dist1 12.59 cm , Dist2 12.59 cm
# Dist1 12.93 cm , Dist2 12.93 cm
# Dist1 12.98 cm , Dist2 12.98 cm
# Dist1 12.97 cm , Dist2 12.97 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.9 cm , Dist2 11.9 cm
# Dist1 11.95 cm , Dist2 11.95 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 1799.87 cm , Dist2 1799.83 cm
# Dist1 11.97 cm , Dist2 11.97 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 1800.85 cm , Dist2 1800.81 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.98 cm , Dist2 11.98 cm
# Dist1 11.97 cm , Dist2 11.97 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 52.91 cm , Dist2 52.91 cm
# Dist1 3.82 cm , Dist2 3.82 cm
# detect
# Dist1 1803.39 cm , Dist2 1803.35 cm
# Dist1 24.12 cm , Dist2 24.12 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 8.64 cm , Dist2 8.64 cm
# detect
# Dist1 20.98 cm , Dist2 20.98 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 2.46 cm , Dist2 2.46 cm
# detect
# Dist1 11.95 cm , Dist2 11.95 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.95 cm , Dist2 11.95 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.95 cm , Dist2 11.95 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 12.74 cm , Dist2 12.74 cm
# Dist1 11.93 cm , Dist2 11.92 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 12.25 cm , Dist2 12.25 cm
# Dist1 1801.66 cm , Dist2 1801.62 cm
# Dist1 11.93 cm , Dist2 11.92 cm
# Dist1 11.94 cm , Dist2 11.94 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 22.34 cm , Dist2 22.34 cm
# Dist1 1797.76 cm , Dist2 1797.72 cm
# Dist1 14.56 cm , Dist2 14.56 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.9 cm , Dist2 11.9 cm
# Dist1 1817.23 cm , Dist2 1817.19 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.5 cm , Dist2 11.5 cm
# Dist1 11.58 cm , Dist2 11.58 cm
# Dist1 11.93 cm , Dist2 11.93 cm
# Dist1 1807.06 cm , Dist2 1807.02 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 1795.53 cm , Dist2 1795.49 cm
# Dist1 11.87 cm , Dist2 11.87 cm
# Dist1 11.91 cm , Dist2 11.91 cm
# Dist1 11.95 cm , Dist2 11.95 cm
# Dist1 12.96 cm , Dist2 12.96 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 1794.69 cm , Dist2 1794.65 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.96 cm , Dist2 11.96 cm
# Dist1 11.97 cm , Dist2 11.97 cm
# Dist1 11.94 cm , Dist2 11.94 cm
# Dist1 11.92 cm , Dist2 11.92 cm
# Dist1 11.6 cm , Dist2 11.6 cm
# Dist1 9.87 cm , Dist2 9.87 cm
# detect
# Dist1 24.71 cm , Dist2 24.71 cm
# Dist1 7.84 cm , Dist2 7.84 cm
# detect
# Dist1 7.83 cm , Dist2 7.83 cm
# detect
# Dist1 7.2 cm , Dist2 7.2 cm
# detect
# Dist1 6.24 cm , Dist2 6.24 cm
# detect
# Dist1 7.18 cm , Dist2 7.18 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.87 cm , Dist2 6.87 cm
# detect
# Dist1 6.86 cm , Dist2 6.86 cm
# detect
# Dist1 7.22 cm , Dist2 7.22 cm
# detect
# Dist1 6.25 cm , Dist2 6.25 cm
# detect
# Dist1 6.23 cm , Dist2 6.23 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.21 cm , Dist2 6.21 cm
# detect
# Dist1 6.21 cm , Dist2 6.21 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.24 cm , Dist2 6.24 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.56 cm , Dist2 6.56 cm
# detect
# Dist1 6.21 cm , Dist2 6.21 cm
# detect
# Dist1 6.21 cm , Dist2 6.21 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 1783.66 cm , Dist2 1783.62 cm
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.56 cm , Dist2 6.56 cm
# detect
# Dist1 1785.15 cm , Dist2 1785.11 cm
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.24 cm , Dist2 6.24 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.55 cm , Dist2 6.55 cm
# detect
# Dist1 6.2 cm , Dist2 6.2 cm
# detect
# Dist1 6.0 cm , Dist2 6.0 cm
# detect
# Dist1 6.22 cm , Dist2 6.22 cm
# detect
# Dist1 1785.11 cm , Dist2 1785.07 cm
# Dist1 9.21 cm , Dist2 9.21 cm
# detect
# Dist1 1786.58 cm , Dist2 1786.54 cm
# Dist1 6.56 cm , Dist2 6.56 cm
# detect
# Dist1 6.53 cm , Dist2 6.53 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.49 cm , Dist2 6.49 cm
# detect
# Dist1 6.55 cm , Dist2 6.55 cm
# detect
# Dist1 6.55 cm , Dist2 6.55 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 5.59 cm , Dist2 5.59 cm
# detect
# Dist1 6.55 cm , Dist2 6.55 cm
# detect
# Dist1 5.58 cm , Dist2 5.58 cm
# detect
# Dist1 5.58 cm , Dist2 5.58 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 6.54 cm , Dist2 6.54 cm
# detect
# Dist1 143.22 cm , Dist2 143.21 cm
# Dist1 143.43 cm , Dist2 143.43 cm
# Dist1 208.31 cm , Dist2 208.3 cm
# Dist1 211.64 cm , Dist2 211.64 cm
# Dist1 202.52 cm , Dist2 202.52 cm
# Dist1 214.6 cm , Dist2 214.59 cm
# Dist1 214.67 cm , Dist2 214.66 cm
# Dist1 2225.54 cm , Dist2 2225.49 cm
# Dist1 219.01 cm , Dist2 219.01 cm
# Dist1 2236.23 cm , Dist2 2236.19 cm
# Dist1 7.35 cm , Dist2 7.35 cm
# detect
# Dist1 32454.93 cm , Dist2 32454.22 cm
# Dist1 420288.87 cm , Dist2 420279.62 cm
# Dist1 192.68 cm , Dist2 192.68 cm
# Dist1 88.97 cm , Dist2 88.97 cm
# Dist1 50.65 cm , Dist2 50.65 cm
# Dist1 89.59 cm , Dist2 89.59 cm
# Dist1 2100.11 cm , Dist2 2100.06 cm
# Dist1 203.68 cm , Dist2 203.67 cm
# Dist1 207.49 cm , Dist2 207.48 cm
# Dist1 0.09 cm , Dist2 0.09 cm
# detect
# Dist1 1930.94 cm , Dist2 1930.89 cm
# Dist1 207.42 cm , Dist2 207.42 cm
# Dist1 140.74 cm , Dist2 140.74 cm
# Dist1 0.06 cm , Dist2 0.06 cm
# detect
# Dist1 1932.42 cm , Dist2 1932.38 cm
# Dist1 198.29 cm , Dist2 198.29 cm
# Dist1 95.75 cm , Dist2 95.75 cm
# Dist1 1873.57 cm , Dist2 1873.53 cm
# Dist1 136.76 cm , Dist2 136.75 cm
# Dist1 0.03 cm , Dist2 0.03 cm
# detect
# Dist1 1930.64 cm , Dist2 1930.59 cm
# Dist1 204.49 cm , Dist2 204.48 cm
# Dist1 204.62 cm , Dist2 204.62 cm
# Dist1 205.31 cm , Dist2 205.31 cm
# Dist1 205.73 cm , Dist2 205.72 cm
# Dist1 205.4 cm , Dist2 205.4 cm
# Dist1 208.85 cm , Dist2 208.85 cm
# Dist1 0.12 cm , Dist2 0.12 cm
# detect
# Dist1 1929.95 cm , Dist2 1929.91 cm
# Dist1 0.55 cm , Dist2 0.55 cm
# detect
# Dist1 1931.37 cm , Dist2 1931.32 cm
# Dist1 207.48 cm , Dist2 207.47 cm
# Dist1 224.25 cm , Dist2 224.24 cm
# Dist1 191.96 cm , Dist2 191.96 cm
# Dist1 218.15 cm , Dist2 218.15 cm
# Dist1 214.92 cm , Dist2 214.91 cm
# Dist1 212.51 cm , Dist2 212.51 cm
# Dist1 211.56 cm , Dist2 211.55 cm
# Dist1 204.44 cm , Dist2 204.43 cm
# Dist1 192.01 cm , Dist2 192.01 cm
# Dist1 221.8 cm , Dist2 221.79 cm
# Dist1 215.34 cm , Dist2 215.33 cm
# Dist1 214.49 cm , Dist2 214.49 cm
# Dist1 211.23 cm , Dist2 211.23 cm
# Dist1 207.57 cm , Dist2 207.56 cm
# Dist1 207.06 cm , Dist2 207.06 cm
# Dist1 212.38 cm , Dist2 212.38 cm
# Dist1 209.19 cm , Dist2 209.19 cm
# Dist1 212.16 cm , Dist2 212.16 cm
# Dist1 211.17 cm , Dist2 211.17 cm
# Dist1 210.81 cm , Dist2 210.8 cm
# Dist1 208.78 cm , Dist2 208.78 cm
# Dist1 175.11 cm , Dist2 175.11 cm
# Dist1 209.46 cm , Dist2 209.46 cm
# Dist1 182.3 cm , Dist2 182.3 cm
# Dist1 207.29 cm , Dist2 207.28 cm
# Dist1 169.68 cm , Dist2 169.67 cm
# Dist1 204.76 cm , Dist2 204.76 cm
# Dist1 202.93 cm , Dist2 202.92 cm
# Dist1 191.51 cm , Dist2 191.5 cm
# Dist1 203.22 cm , Dist2 203.22 cm
# Dist1 209.57 cm , Dist2 209.56 cm
# Dist1 7971.39 cm , Dist2 7971.21 cm
# Dist1 9713.69 cm , Dist2 9713.48 cm
# Dist1 11711.99 cm , Dist2 11711.73 cm
# Dist1 13722.31 cm , Dist2 13722.01 cm
# Dist1 2848.01 cm , Dist2 2847.95 cm
# Dist1 4853.88 cm , Dist2 4853.77 cm
# Dist1 12177.9 cm , Dist2 12177.63 cm
# Dist1 35882.56 cm , Dist2 35881.77 cm
# Dist1 41048.29 cm , Dist2 41047.39 cm
# Dist1 239.73 cm , Dist2 239.73 cm
# Dist1 188.79 cm , Dist2 188.79 cm
# Dist1 2234.74 cm , Dist2 2234.69 cm
# Dist1 222.11 cm , Dist2 222.11 cm
# Dist1 230.98 cm , Dist2 230.98 cm
# Dist1 235.55 cm , Dist2 235.55 cm
# Dist1 229.48 cm , Dist2 229.48 cm
# Dist1 7147.31 cm , Dist2 7147.15 cm
# Dist1 9144.99 cm , Dist2 9144.79 cm
# Dist1 10894.87 cm , Dist2 10894.63 cm
# Dist1 12877.62 cm , Dist2 12877.34 cm
# Dist1 248.58 cm , Dist2 248.58 cm
# Dist1 2259.04 cm , Dist2 2258.99 cm
# Dist1 4269.7 cm , Dist2 4269.61 cm
# Dist1 229.83 cm , Dist2 229.83 cm
# Dist1 2242.72 cm , Dist2 2242.67 cm
# Dist1 232.24 cm , Dist2 232.23 cm
# Dist1 237.5 cm , Dist2 237.49 cm
# Dist1 233.95 cm , Dist2 233.94 cm
# Dist1 236.0 cm , Dist2 236.0 cm
# Dist1 239.93 cm , Dist2 239.92 cm
# Dist1 242.71 cm , Dist2 242.7 cm
# Dist1 250.64 cm , Dist2 250.63 cm
# Dist1 2002.8 cm , Dist2 2002.75 cm
# Dist1 3994.22 cm , Dist2 3994.13 cm
# Dist1 10589.53 cm , Dist2 10589.29 cm
# Dist1 12603.64 cm , Dist2 12603.36 cm
# Dist1 16048.24 cm , Dist2 16047.89 cm
# Dist1 18349.91 cm , Dist2 18349.5 cm
# Dist1 20362.69 cm , Dist2 20362.24 cm
# Dist1 50812.71 cm , Dist2 50811.59 cm
# Dist1 231.2 cm , Dist2 231.2 cm
# Dist1 231.85 cm , Dist2 231.84 cm
# Dist1 231.43 cm , Dist2 231.42 cm
# Dist1 229.75 cm , Dist2 229.74 cm
# Dist1 229.65 cm , Dist2 229.65 cm
# Dist1 229.83 cm , Dist2 229.82 cm
# Dist1 230.12 cm , Dist2 230.12 cm
# Dist1 2242.14 cm , Dist2 2242.09 cm
# Dist1 4253.0 cm , Dist2 4252.9 cm
# Dist1 231.36 cm , Dist2 231.36 cm
# Dist1 231.68 cm , Dist2 231.67 cm
# Dist1 231.52 cm , Dist2 231.52 cm
# Dist1 0.12 cm , Dist2 0.12 cm
# detect
# Dist1 1879.9 cm , Dist2 1879.86 cm
# Dist1 3676.83 cm , Dist2 3676.75 cm
# Dist1 207.81 cm , Dist2 207.81 cm
# Dist1 0.7 cm , Dist2 0.7 cm
# detect
# Dist1 1930.01 cm , Dist2 1929.97 cm
# Dist1 0.75 cm , Dist2 0.75 cm
# detect
# Dist1 1931.68 cm , Dist2 1931.63 cm
# Dist1 207.81 cm , Dist2 207.8 cm
# Dist1 0.47 cm , Dist2 0.47 cm
# detect
# Dist1 1931.81 cm , Dist2 1931.76 cm
# Dist1 206.36 cm , Dist2 206.36 cm
# Dist1 205.69 cm , Dist2 205.69 cm
# Dist1 207.63 cm , Dist2 207.62 cm
# Dist1 205.61 cm , Dist2 205.6 cm
# Dist1 204.34 cm , Dist2 204.33 cm
# Dist1 205.46 cm , Dist2 205.45 cm
# Dist1 203.4 cm , Dist2 203.39 cm
# Dist1 4.74 cm , Dist2 4.74 cm
# detect
# Dist1 -628424.88 cm , Dist2 -628411.06 cm
# detect
# Dist1 113340.59 cm , Dist2 113338.1 cm
# Dist1 37.99 cm , Dist2 37.99 cm
# Dist1 2171.27 cm , Dist2 2171.22 cm
# Dist1 93390.93 cm , Dist2 93388.88 cm
# Dist1 -1780.26 cm , Dist2 -1780.22 cm
# detect
# Dist1 -10505.68 cm , Dist2 -10505.45 cm
# detect
# Dist1 36148.64 cm , Dist2 36147.85 cm
# Dist1 135.87 cm , Dist2 135.87 cm
# Dist1 2449.07 cm , Dist2 2449.02 cm
# Dist1 4458.48 cm , Dist2 4458.38 cm
# Dist1 68.3 cm , Dist2 68.3 cm
# Dist1 1859.44 cm , Dist2 1859.4 cm
# Dist1 143.84 cm , Dist2 143.84 cm
# Dist1 -1785.84 cm , Dist2 -1785.8 cm
# detect
# Dist1 3122.19 cm , Dist2 3122.12 cm
# Dist1 0.02 cm , Dist2 0.02 cm
# detect
# Dist1 220.78 cm , Dist2 220.78 cm
# Dist1 3410.98 cm , Dist2 3410.91 cm
# Dist1 5216.77 cm , Dist2 5216.65 cm
# Dist1 94717.61 cm , Dist2 94715.53 cm
# Dist1 0.03 cm , Dist2 0.03 cm
# detect
# Dist1 0.02 cm , Dist2 0.02 cm
# detect
# Dist1 -1738.88 cm , Dist2 -1738.84 cm
# detect
# Dist1 1766.81 cm , Dist2 1766.77 cm
# Dist1 3757.07 cm , Dist2 3756.99 cm
# Dist1 6151.89 cm , Dist2 6151.76 cm
# Dist1 11256.87 cm , Dist2 11256.62 cm
# Dist1 88644.23 cm , Dist2 88642.27 cm
# Dist1 110786.07 cm , Dist2 110783.63 cm
# Dist1 265310.59 cm , Dist2 265304.75 cm
# Dist1 -1742.95 cm , Dist2 -1742.91 cm
# detect
# Dist1 1779.27 cm , Dist2 1779.23 cm
# Dist1 141302.06 cm , Dist2 141298.95 cm
# Dist1 -8676.8 cm , Dist2 -8676.61 cm
# detect
# Dist1 9583.48 cm , Dist2 9583.27 cm
# Dist1 -21663.06 cm , Dist2 -21662.58 cm
# detect
# Dist1 75801.2 cm , Dist2 75799.53 cm
# Dist1 -78286381.34 cm , Dist2 -78284659.04 cm
# detect
# Dist1 4371.82 cm , Dist2 4371.72 cm
# Dist1 0.05 cm , Dist2 0.05 cm
# detect
# Dist1 -2388450.22 cm , Dist2 -2388397.67 cm
# detect
# Dist1 0.03 cm , Dist2 0.03 cm
# detect
# Dist1 54019.51 cm , Dist2 54018.32 cm
# Dist1 -6640.65 cm , Dist2 -6640.51 cm
# detect
# Dist1 5608.74 cm , Dist2 5608.61 cm
# Dist1 -13471.88 cm , Dist2 -13471.58 cm
# detect
# Dist1 14166.85 cm , Dist2 14166.54 cm
# Dist1 -8349.43 cm , Dist2 -8349.25 cm
# detect
# Dist1 10111.89 cm , Dist2 10111.66 cm
# Dist1 -11905.87 cm , Dist2 -11905.61 cm
# detect
# Dist1 9712.12 cm , Dist2 9711.91 cm
# Dist1 0.03 cm , Dist2 0.03 cm
# detect
# Dist1 9885.04 cm , Dist2 9884.83 cm
